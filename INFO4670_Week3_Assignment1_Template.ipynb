# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayu8805/Mayuresh_INFO4670_Fall2026/blob/main/INFO4670_Week3_Assignment1_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Mayuresh Kamble    **Date:** 09/06/2026
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd

students = pd.read_csv("/student_records.csv")
weekly = pd.read_csv("/weekly_activity.csv")
course_enrollments = pd.read_csv("/course_enrollments.csv")

students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "/"   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
plt.figure(figsize=(8, 5))

sns.histplot(
    data=students,
    x="work_hours_per_week",
    bins=15,
    color=NAVY
)

plt.title("Distribution of Students' Work Hours per Week")
plt.xlabel("Work Hours per Week (hours)")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
#
# Scope: This histogram shows the distribution of reported work hours per week for 2,027 students.
#
# Track: The chart answers how many hours students typically work and how spread out those work hours are.
#
# Articulate: The typical student reports about 18 hours of work per week. The middle 50% of students are between about 10 and 25 hours per week. The distribution has a fairly wide spread, ranging from -12 to 40 hours.
#
# Respond: The negative work-hour values are unexpected because hours worked should not normally be negative. I would investigate those records later to determine whether they represent data-entry or coding issues, rather than changing them for this assignment.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
major_counts = students["major"].value_counts().sort_values()

plt.figure(figsize=(9, 6))

sns.barplot(
    x=major_counts.values,
    y=major_counts.index,
    color=NAVY
)

plt.title("Student Enrollment by Major")
plt.xlabel("Number of Students")
plt.ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# Scope: This bar chart compares the number of students in each major.
#
# Track: It answers which majors have the largest and smallest student populations.
#
# Articulate: Cybersecurity has the largest enrollment with 530 students. Information Science and Data Science each have 285 students, while Information Technology has 283. The smallest groups are Information Science and Info Technology, with 32 students each.
#
# Respond: The major names appear to have inconsistencies, such as “Cybersecurity” and “Cyber Security” being separate categories. This is something I would investigate because it may affect the enrollment comparison.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(
    data=students,
    x="major",
    y="final_gpa"
)

plt.title("Final GPA Distribution by Major")
plt.xlabel("Major")
plt.ylabel("Final GPA")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# Scope: This box plot compares final GPA distributions across majors.
#
# Track: It shows differences in typical GPA and the spread of GPA within each major.
#
# Articulate: Median GPA varies across majors. Cyber Security has a median around 2.50, while Cybersecurity is around 2.41. Most majors have medians between roughly 2.25 and 2.50, with substantial variation within each major.
#
# Respond: Some major names appear duplicated with different formatting, such as Cybersecurity/Cyber Security and Data Science/DataScience. I would investigate whether these should represent the same major.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
plt.figure(figsize=(8, 5))

sns.regplot(
    data=students,
    x="commute_miles",
    y="final_gpa",
    scatter_kws={"alpha": 0.4},
    line_kws={"color": RUST}
)

plt.title("Commute Distance vs. Final GPA")
plt.xlabel("Commute Distance (miles)")
plt.ylabel("Final GPA")
plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# Scope: This scatterplot compares commute distance with final GPA for the students in the dataset.
#
# Track: It examines whether there is an association between commuting farther and having a different final GPA.
#
# Articulate: The trend line slopes downward, indicating a negative association. The correlation is approximately -0.30, meaning students with longer commutes tend to have somewhat lower GPAs. However, the points are widely scattered, so commute distance does not explain all of the variation in GPA.
#
# Respond: The negative relationship is worth investigating, but this chart does not establish that commuting causes lower GPA. Other factors such as work hours, housing, or study time could also contribute.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
weekly_avg = weekly.groupby("week", as_index=False)["minutes_active"].mean()

plt.figure(figsize=(9, 5))

sns.lineplot(
    data=weekly_avg,
    x="week",
    y="minutes_active",
    marker="o",
    color=NAVY
)

plt.title("Average Weekly LMS Activity")
plt.xlabel("Week")
plt.ylabel("Average Minutes Active")
plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# Scope: This line chart shows average LMS activity across 16 weeks.
#
# Track: It answers how student LMS activity changes from week to week.
#
# Articulate: Average activity is around 210 minutes for most weeks. Week 9 is a major exception, dropping to about 89 minutes, while the other weeks remain close to 210 minutes.
#
# Respond: The sharp Week 9 drop is unexpected and should be investigated. It could represent a data collection issue, missing activity, or a real change in student behavior. I would investigate it rather than changing the data.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** Do GPA distributions differ by housing?

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

# %%
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=students,
    x="housing",
    y="final_gpa"
)

plt.title("Final GPA by Housing Type")
plt.xlabel("Housing Type")
plt.ylabel("Final GPA")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*
#
# Scope: This box plot compares final GPA across different housing categories.
#
# Track: It examines whether students living in different housing situations have different GPA distributions.
#
# Articulate: The median GPA differs across housing groups. The off-campus and with-family groups have somewhat higher median GPAs than the on-campus group, although there is considerable overlap in the distributions.
#
# Respond: The housing categories have inconsistent capitalization, such as “On-Campus” and “on-campus.” I would investigate whether these represent the same category before drawing stronger conclusions.

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
